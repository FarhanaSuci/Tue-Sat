# %%
import pandas as pd

# %%
pay=pd.read_csv('DataProject1.csv')

# %%
pay
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN    $107790.00
# ...

# %%
pay.shape
# Out:
# (32658, 8)

# %%
pay.describe(include='all')
# Out:
#                       Name      Job Titles Department Full or Part-Time  \
# count                32658           32658      32658             32658
# unique               32350            1095         36                 2
# top     HERNANDEZ,  JUAN C  POLICE OFFICER     POLICE                 F
# freq                     5            9393      12973             30676
# mean                   NaN             NaN        NaN               NaN
# std                    NaN             NaN        NaN               NaN
# min                    NaN             NaN        NaN               NaN
# 25%                    NaN             NaN        NaN               NaN
# 50%                    NaN             NaN        NaN               NaN
# 75%                    NaN             NaN        NaN               NaN
# max                    NaN             NaN        NaN               NaN
#
#        Salary or Hourly  Typical Hours Annual Salary Hourly Rate
# ...

# %%
pay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32658 entries, 0 to 32657
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               32658 non-null  object
#  1   Job Titles         32658 non-null  object
#  2   Department         32658 non-null  object
#  3   Full or Part-Time  32658 non-null  object
#  4   Salary or Hourly   32658 non-null  object
#  5   Typical Hours      7883 non-null   float64
#  6   Annual Salary      24775 non-null  object
#  7   Hourly Rate        7883 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 2.0+ MB

# %%
pay.head(5)
# Out:
#                Name      Job Titles Department Full or Part-Time  \
# 0  ALLISON,  PAUL W      LIEUTENANT       FIRE                 F
# 1   BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 2   COOPER,  JOHN E  LIEUTENANT-EMT       FIRE                 F
# 3  CRESPO,  VILMA I      STAFF ASST        LAW                 F
# 4  DOLAN,  ROBERT J        SERGEANT     POLICE                 F
#
#   Salary or Hourly  Typical Hours Annual Salary Hourly Rate
# 0           Salary            NaN    $107790.00         NaN
# 1           Salary            NaN    $104628.00         NaN
# 2           Salary            NaN    $114324.00         NaN
# 3           Salary            NaN     $76932.00         NaN
# 4           Salary            NaN    $111474.00         NaN

# %%
pay.sample(5)
# Out:
#                         Name                              Job Titles  \
# 8665       FIGIEL,  ROBERT R                 POOL MOTOR TRUCK DRIVER
# 25044           ROE,  JACK A                         FIREFIGHTER-EMT
# 3317       BRYANT,  SANDRA G  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 24098     REIMER,  RICHARD R                          POLICE OFFICER
# 29861  VALDIVIA,  HERIBERTO                FIREFIGHTER-EMT (RECRUIT)
#
#       Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 8665    AVIATION                 F           Hourly           40.0
# 25044       FIRE                 F           Salary            NaN
# 3317      POLICE                 F           Salary            NaN
# 24098     POLICE                 F           Salary            NaN
# 29861       FIRE                 F           Salary            NaN
#
#       Annual Salary Hourly Rate
# 8665            NaN      $35.60
# 25044     $89148.00         NaN
# 3317     $100980.00         NaN
# ...

# %%
print('Max typical Hours',pay['Typical Hours'].max())
print('Minimum typical Hours',pay['Typical Hours'].min())
print('Average typical Hours',pay['Typical Hours'].mean())
# Out:
# Max typical Hours 40.0
# Minimum typical Hours 10.0
# Average typical Hours 34.69871876189268

# %%
pay.groupby('Salary or Hourly').count()[['Name']]
# Out:
#                    Name
# Salary or Hourly
# Hourly             7883
# Salary            24775

# %%
pay['Salary or Hourly'].value_counts()
# Out:
# Salary or Hourly
# Salary    24775
# Hourly     7883
# Name: count, dtype: int64

# %%
pay['Department'].value_counts().head(1)
# Out:
# Department
# POLICE    12973
# Name: count, dtype: int64

# %%
#How many employees are on Salary and how many are on Hourly in the Police department?
pay[(pay['Department']=='POLICE')].groupby('Salary or Hourly').count()[['Name']]
# Out:
#                    Name
# Salary or Hourly
# Hourly               32
# Salary            12941

# %%
df=pay[pay['Department']=='POLICE']
df['Salary or Hourly'].value_counts()
# Out:
# Salary or Hourly
# Salary    12941
# Hourly       32
# Name: count, dtype: int64

# %%
pay.head(5)
# Out:
#                Name      Job Titles Department Full or Part-Time  \
# 0  ALLISON,  PAUL W      LIEUTENANT       FIRE                 F
# 1   BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 2   COOPER,  JOHN E  LIEUTENANT-EMT       FIRE                 F
# 3  CRESPO,  VILMA I      STAFF ASST        LAW                 F
# 4  DOLAN,  ROBERT J        SERGEANT     POLICE                 F
#
#   Salary or Hourly  Typical Hours Annual Salary Hourly Rate
# 0           Salary            NaN    $107790.00         NaN
# 1           Salary            NaN    $104628.00         NaN
# 2           Salary            NaN    $114324.00         NaN
# 3           Salary            NaN     $76932.00         NaN
# 4           Salary            NaN    $111474.00         NaN

# %%
pay['Salary']=pay['Annual Salary'].str.replace('$','').astype(float)

# %%
pay.head(5)
# Out:
#                Name      Job Titles Department Full or Part-Time  \
# 0  ALLISON,  PAUL W      LIEUTENANT       FIRE                 F
# 1   BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 2   COOPER,  JOHN E  LIEUTENANT-EMT       FIRE                 F
# 3  CRESPO,  VILMA I      STAFF ASST        LAW                 F
# 4  DOLAN,  ROBERT J        SERGEANT     POLICE                 F
#
#   Salary or Hourly  Typical Hours Annual Salary Hourly Rate    Salary
# 0           Salary            NaN    $107790.00         NaN  107790.0
# 1           Salary            NaN    $104628.00         NaN  104628.0
# 2           Salary            NaN    $114324.00         NaN  114324.0
# 3           Salary            NaN     $76932.00         NaN   76932.0
# 4           Salary            NaN    $111474.00         NaN  111474.0

# %%
pay['Salary'].max()
# Out:
# 300000.0

# %%
pay['Salary'].min()
# Out:
# 0.96

# %%
pay['Salary'].mean()
# Out:
# 87512.78024137235

# %%
pay[pay['Salary']==pay['Salary'].max()][['Name']]
# Out:
#                   Name
# 8310  EVANS,  GINGER S

# %%
pay[pay['Salary']==pay['Salary'].min()][['Name']]
# Out:
#                  Name
# 15387  KOCH,  STEVEN

# %%
pay.iloc[pay['Salary'].idxmin()][['Name']]
# Out:
# Name    KOCH,  STEVEN
# Name: 15387, dtype: object

# %%
pay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32658 entries, 0 to 32657
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               32658 non-null  object
#  1   Job Titles         32658 non-null  object
#  2   Department         32658 non-null  object
#  3   Full or Part-Time  32658 non-null  object
#  4   Salary or Hourly   32658 non-null  object
#  5   Typical Hours      7883 non-null   float64
#  6   Annual Salary      24775 non-null  object
#  7   Hourly Rate        7883 non-null   object
#  8   Salary             24775 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 2.2+ MB

# %%
pay
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN    $107790.00
# ...

# %%
pay['H_Rate']=pay['Hourly Rate'].str.replace('$','').astype(float)

# %%
pay
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN    $107790.00
# ...

# %%
pay['Hourly Rate'].unique()
# Out:
# array([nan, '$14.51', '$19.66', '$46.10', '$35.60', '$2.65', '$17.50',
#        '$20.77', '$25.10', '$36.21', '$44.88', '$37.25', '$48.25',
#        '$40.20', '$36.13', '$28.48', '$32.25', '$21.20', '$20.12',
#        '$13.15', '$21.98', '$15.07', '$19.50', '$32.04', '$34.57',
#        '$8.25', '$47.44', '$46.35', '$32.59', '$36.22', '$14.40',
#        '$30.51', '$45.07', '$19.19', '$20.11', '$49.10', '$14.75',
#        '$18.34', '$9.46', '$44.25', '$22.14', '$35.57', '$21.43',
#        '$23.31', '$44.55', '$16.17', '$50.25', '$38.33', '$12.00',
#        '$53.10', '$12.49', '$24.42', '$52.18', '$13.80', '$41.10',
#        '$22.13', '$41.70', '$37.45', '$32.16', '$53.90', '$45.35',
#        '$17.15', '$19.00', '$10.00', '$30.20', '$17.25', '$16.71',
#        '$21.09', '$45.43', '$22.00', '$47.50', '$15.00', '$52.10',
#        '$13.00', '$48.90', '$38.14', '$33.56', '$22.12', '$9.27',
#        '$13.75', '$45.75', '$24.12', '$8.50', '$71.29', '$20.88',
# ...

# %%
pay['H_Rate'].max()
# Out:
# 96.0

# %%
pay['H_Rate'].min()
# Out:
# 2.65

# %%
pay['H_Rate'].mean()
# Out:
# 32.86819231257135

# %%
pay[pay['H_Rate']==pay['H_Rate'].max()][['Name']]
# Out:
#                  Name
# 14317  JONES,  JOHN W

# %%
pay.iloc[pay['H_Rate'].idxmax()]
# Out:
# Name                 JONES,  JOHN W
# Job Titles             PSYCHIATRIST
# Department                   HEALTH
# Full or Part-Time                 F
# Salary or Hourly             Hourly
# Typical Hours                  35.0
# Annual Salary                   NaN
# Hourly Rate                  $96.00
# Salary                          NaN
# H_Rate                         96.0
# Name: 14317, dtype: object

# %%
# How many employees are earning less than the average Hourly Rate?
pay[(pay['H_Rate']<pay['H_Rate'].mean())].count()[['Name']]
# Out:
# Name    2791
# dtype: int64

# %%
#How many employees are paid hourly and they have full-time job?
pay[(pay['Full or Part-Time']=='F') & (pay['Salary or Hourly']=='Hourly')].count()[['Name']]
# Out:
# Name    5906
# dtype: int64

# %%
# Find the full-time employees who are working at hourly rate of $10.00?
pay[(pay['Full or Part-Time']=='F') &( pay['Hourly Rate']=='$10.00')]
# Out:
#                        Name          Job Titles       Department  \
# 1232      AYALA JR,  JESUS       STUDENT INTERN  HUMAN RESOURCES
# 4522   CERVANTES,  BIANCA A      STUDENT INTERN    BUDGET & MGMT
# 6476     DAVILA,  ROBERTO A     ALDERMANIC AIDE     CITY COUNCIL
# 16474         LEVY,  ETHAN   CLERK CITY COUNCIL     CITY COUNCIL
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 1232                  F           Hourly           35.0           NaN
# 4522                  F           Hourly           35.0           NaN
# 6476                  F           Hourly           35.0           NaN
# 16474                 F           Hourly           35.0           NaN
#
#       Hourly Rate  Salary  H_Rate
# 1232       $10.00     NaN    10.0
# 4522       $10.00     NaN    10.0
# 6476       $10.00     NaN    10.0
# 16474      $10.00     NaN    10.0

# %%
#How many unique Job Titles are there in the data?
pay['Job Titles'].nunique()
# Out:
# 1095

# %%
# What was the average Salary of the employees in each department?
pay.groupby('Department')[['Salary']].mean()
# Out:
#                              Salary
# Department
# ADMIN HEARNG           78912.947368
# ANIMAL CONTRL          66089.684211
# AVIATION               76140.018777
# BOARD OF ELECTION      56051.142857
# BOARD OF ETHICS        94552.500000
# BUDGET & MGMT          93925.395349
# BUILDINGS              98864.833534
# BUSINESS AFFAIRS       80446.425000
# CITY CLERK             69762.439024
# CITY COUNCIL           63577.172069
# COMMUNITY DEVELOPMENT  88363.257143
# COPA                   98784.705882
# CULTURAL AFFAIRS       87048.909091
# DISABILITIES           82431.724138
# DoIT                   99681.029703
# FAMILY & SUPPORT       79013.588785
# FINANCE                73276.364662
# FIRE                   97762.348662
# GENERAL SERVICES       83095.528390
# HEALTH                 85488.210938
# HUMAN RELATIONS        93778.588235
# HUMAN RESOURCES        79851.761194
# INSPECTOR GEN          84030.666667
# IPRA                   94429.285714
# ...

# %%
#what is the job title of 'AGAR, BULENT B'?
pay[pay['Name']=='AGAR,  BULENT B'][['Job Titles']]
# Out:
#                    Job Titles
# 230  CHIEF ENGINEER OF SEWERS

# %%
name=input('Enter a name ')
pay[pay['Name']==name][['Job Titles']]
# Out:
# Enter a name  AGAR,  BULENT B
#                    Job Titles
# 230  CHIEF ENGINEER OF SEWERS

# %%
#What are the top most common job titles?
pay['Job Titles'].value_counts().head(1)
# Out:
# Job Titles
# POLICE OFFICER    9393
# Name: count, dtype: int64

# %%
#. How many people have the word 'officer' in their job title? (This is pretty tricky)
pay[pay['Job Titles'].str.contains('officer',case=False)].count()[['Name']]
# Out:
# Name    11101
# dtype: int64

# %%
pay
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN    $107790.00
# ...

# %%
pay.to_csv('store.csv')

# %%
def find_string(title):
    if 'officer' in title.lower():
        return True
    else:
        return False

# %%
pay['Job Titles'].apply(find_string).sum()
# Out:
# 11101
