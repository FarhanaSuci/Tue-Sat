# %% [markdown]
# # Seaborn: statistical data visualization -- exercises overview
#
# Hi guys,<br>
#
# Great work! It's time to practice and test the skills you have just learned. <br>
#
# We will use **tips**, **iris** and another very famous dataset **titanic** for these exercises. These datasets are included in the seaborn's built-in dataset library.<br>
# Let's do some exploratory data analysis using seaborn and present useful plots for data visualization!<br>

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Do the following tasks:**
# * set style to '`white`'
# * load titanic dataset into '`titanic`', tips into '`tips`' and iris into '`iris`'

# %%
sns.set_style('white')
titanic=sns.load_dataset('titanic')
tips=sns.load_dataset('tips')
iris=sns.load_dataset('iris')
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# **Recreate the plot below. Use tips dataset. Hint: pay attention to x and y labels.**

# %%
sns.boxplot(x="day", y="tip", hue="sex", data=tips, palette={"Male": "blue", "Female": "green"})
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# **Recreate the plot below. Use tips dataset. Hint: pay attention to x and y labels.**

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %% [markdown]
# **Recreate the distplot given below. Use titanic dataset. Hint: pay attention to x and y labels.**

# %%
sns.distplot(titanic['fare'],kde=False,bins=30,color='green')
# Out:
# <Axes: xlabel='fare'>

# %% [markdown]
# **Recreate the boxplot below using titanic dataset. Hint: pay attention to x and y labels.**

# %%
sns.boxplot(x="class", y="age", hue="alive", data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %% [markdown]
# **Recreate the plot below using titanic dataset. Hint: pay attention to x and y labels.**

# %%
sns.jointplot(x='fare',y='age',data=titanic)

# %% [markdown]
# **Recreate the plot below. Use titanic dataset. **

# %%
sns.boxplot(x='class',y='age',data=titanic, palette={"First": "b", "Third": "orange","Second":"green"})
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %% [markdown]
# **Can you plot how many male and female were on titanic? Separate them based on their class.**

# %%
sns.countplot(x="sex", hue="class",data=titanic,palette={"First": "b", "Third": "brown","Second":"green"})
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# **Recreate the plot below. Use titanic dataset. Hint: Matrix plots**

# %%
from sklearn.preprocessing import LabelEncoder
lc=LabelEncoder()
titanic['adult_male']=lc.fit_transform(titanic['adult_male'])
titanic['alone']=lc.fit_transform(titanic['alone'])

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town  alone
# 0      man           1  NaN  Southampton      0
# 1    woman           0    C    Cherbourg      0
# 2    woman           0  NaN  Southampton      1
# 3    woman           0    C  Southampton      0
# 4      man           1  NaN  Southampton      1
# ..     ...         ...  ...          ...    ...
# 886    man           1  NaN  Southampton      1
# 887  woman           0    B  Southampton      1
# 888  woman           0  NaN  Southampton      0
# 889    man           1    C    Cherbourg      1
# 890    man           1  NaN   Queenstown      1
#
# [891 rows x 14 columns]

# %%
titanic.drop('alive',axis=1,inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town  alone
# 0      man           1  NaN  Southampton      0
# 1    woman           0    C    Cherbourg      0
# 2    woman           0  NaN  Southampton      1
# 3    woman           0    C  Southampton      0
# 4      man           1  NaN  Southampton      1
# ..     ...         ...  ...          ...    ...
# 886    man           1  NaN  Southampton      1
# 887  woman           0    B  Southampton      1
# 888  woman           0  NaN  Southampton      0
# 889    man           1    C    Cherbourg      1
# 890    man           1  NaN   Queenstown      1
#
# [891 rows x 14 columns]

# %%
numeric_cols = titanic.select_dtypes(include='number').columns

# Compute the correlation matrix
tc = titanic[numeric_cols].corr()
tc
#sns.heatmap(tc,cmap='coolwarm',annot=True )
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(tc,cmap='coolwarm',annot=True )
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1.0, 'titanic.corr()')

# %%
# Leave this cell empty please.

# %%
#Live Test

# %%
data_dic = {'A':[12,15,45,71],

            'B':[18,26,50,80],

            'C':[32,48,78,93],

            'D':[29,35,63,81]}

# %%
import pandas as pd

# %%
df=pd.DataFrame(data_dic)

# %%
df
# Out:
#     A   B   C   D
# 0  12  18  32  29
# 1  15  26  48  35
# 2  45  50  78  63
# 3  71  80  93  81

# %%
import seaborn as sns

# %%
corelation=df.corr()

# %%
corelation
# Out:
#           A         B         C         D
# A  1.000000  0.995113  0.968494  0.994912
# B  0.995113  1.000000  0.967532  0.988731
# C  0.968494  0.967532  1.000000  0.987630
# D  0.994912  0.988731  0.987630  1.000000

# %%
sns.heatmap(corelation, annot=True)
# Out:
# <Axes: >

# %%
data_dic = {'A':[12,15,45,71],

            'B':[18,26,50,80],

            'C':[32,48,78,93],

            'D':[29,35,63,81]}

import pandas as pd
df=pd.DataFrame(data_dic)
import seaborn as sns
sns.heatmap(df, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Excellent work!
#
# **So far, we are done with the seaborn essentials. We will practice much more in the coming machine learning section!**
